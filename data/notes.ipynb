# %% [markdown]
# ### Thoughts and notes about data
# Ideas for meaningful features after studying https://teamepochgithub.github.io/aicup-birds-radar-detection-tool/
# - Smoothness of trajectory ??
# - lon std
# - lat std
# - height std
# - min/max/mean/std RCS
# - airspeed
