# %% [markdown]
# ## Issues
#
# - Feature configuration selection is not set up yet.
# - 1 degree of latitude is not as much as 1 degree of longitude and circularity score based on that may be grossly inaccurate.
# - W training można coś zrobić z unique observation id.
# - Downsampling Gulls
# - Grid search na Catboost
# - Water Proximity: If you have coordinates, calculate the distance to the nearest body of water. Cormorants are rarely found far from it compared to Gulls.
#
# ### Mniej ważne
# - Możnaby zrobić PCA cache, żeby przygotowywanie danych trwało krócej.
# - Niewykluczone, że trzeba rówineż uwzględnić siłę wiatru (może można sprawdzić w internecie bo mamy timestamps) i policzyć prędkość/ przemieszczenie itd tylko relatywne do tego. To niewykluczone że ma jakieś znaczenie.
# - Czat proponuje wziąć rzędy z test dataset gdzie model ma bardzo wysoką pewność i dodać je do training dataset. Ta technika rzekomo pomagao 1-2%.
# - Chat also suggests some "threshold manipulation" regarding multiclass calibration. I do not know what it is right now though.
# - Log encoding do rcs
# - Target encoding

# %%
from IPython.display import Image, display
#display(Image(filename='images/size_composition_stacked.png'))
#display(Image(filename='images/local_2d_pca_max.png'))

# %% [markdown]
# Keep in mind that this graph is nonetheless heavily influenced by the fact some bird groups are heavily underrepresented in the training set.
